# %% [markdown]
# <a href="https://colab.research.google.com/github/zakir0741/CNN_network/blob/main/CNN_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Tensorflow: Deep learning framework(we'll use it to build/train our model)
# tensorflow_datasets(tfds): To load the Food-101 dataset
# matplotlib.pyplot: For image plotting
# numpy: For numrical operations and predictions

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'food101',
    split=['train', 'validation'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/food101/2.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/food101/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/food101/incomplete.P5ZSM6_2.0.0/food101-train.tfrecord*...:   0%|         …
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/food101/incomplete.P5ZSM6_2.0.0/food101-validation.tfrecord*...:   0%|    …
# Dataset food101 downloaded and prepared to /root/tensorflow_datasets/food101/2.0.0. Subsequent calls will reuse this data.

# %%
print("Total Classes:",ds_info.features['label'].num_classes)
print("Sample Classes:",ds_info.features['label'].names[:10])
# Out:
# Total Classes: 101
# Sample Classes: ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito']

# %%
IMG_SIZE = 224
BATCH_SIZE = 32

def preprocess(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))         # Resize
    image = tf.cast(image, tf.float32) / 255.0                    # Normalize
    return image, label

ds_train = ds_train.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
ds_test = ds_test.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
for images, labels in ds_train.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy())
        label = ds_info.features['label'].int2str(labels[i].numpy())
        plt.title(label)
        plt.axis("off")
    plt.show()

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(101, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
    )

# %%
history = model.fit(ds_train, epochs=5, validation_data=ds_test)
# Out:
# Epoch 1/5
# 2368/2368 ━━━━━━━━━━━━━━━━━━━━ 4092s 2s/step - accuracy: 0.3827 - loss: 2.6028 - val_accuracy: 0.5700 - val_loss: 1.6450
# Epoch 2/5
# 2368/2368 ━━━━━━━━━━━━━━━━━━━━ 4102s 2s/step - accuracy: 0.5774 - loss: 1.6512 - val_accuracy: 0.5863 - val_loss: 1.5851
# Epoch 3/5
# 2368/2368 ━━━━━━━━━━━━━━━━━━━━ 4168s 2s/step - accuracy: 0.6167 - loss: 1.4793 - val_accuracy: 0.5874 - val_loss: 1.5920
# Epoch 4/5
# 2368/2368 ━━━━━━━━━━━━━━━━━━━━ 4162s 2s/step - accuracy: 0.6449 - loss: 1.3623 - val_accuracy: 0.5926 - val_loss: 1.5774
# Epoch 5/5
# 2368/2368 ━━━━━━━━━━━━━━━━━━━━ 4097s 2s/step - accuracy: 0.6637 - loss: 1.2861 - val_accuracy: 0.5868 - val_loss: 1.6182

# %%
loss, accuracy = model.evaluate(ds_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 1040s 1s/step - accuracy: 0.5873 - loss: 1.6257
# Test Accuracy: 58.68%

# %%
class_names = ds_info.features['label'].names

for images, labels in ds_test.take(1):
  image = images[0]
  true_label = class_names[labels[0].numpy()]

  prediction = model.predict(tf.expand_dims(image, axis=0))
  predicted_label = class_names[np.argmax(prediction)]

  plt.imshow(image)
  plt.title(f"predicted: {predicted_label}\nTrue: {true_label}")
  plt.axis('off')
  plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
model.save("food101_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
